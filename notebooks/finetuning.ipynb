# %%
# %cd ..
# !pip install -r requirements.txt wandb
# Out:
# Mounted at /content/drive
# /content/wav2vec2.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.9 MB 28.7 MB/s
# ...
#      |████████████████████████████████| 800 kB 61.9 MB/s
# ...
#      |████████████████████████████████| 41 kB 614 kB/s
# ...
#      |████████████████████████████████| 50 kB 8.0 MB/s
# ...
#      |████████████████████████████████| 5.8 MB 57.0 MB/s
# ...
#      |████████████████████████████████| 182 kB 79.0 MB/s
# ...
#      |████████████████████████████████| 168 kB 71.5 MB/s
# ...
#      |████████████████████████████████| 62 kB 1.8 MB/s
# ...
#      |████████████████████████████████| 168 kB 76.9 MB/s
# ...
#      |████████████████████████████████| 166 kB 81.7 MB/s
# ...
#      |████████████████████████████████| 166 kB 71.8 MB/s
# ...
#      |████████████████████████████████| 162 kB 86.2 MB/s
# ...
#      |████████████████████████████████| 162 kB 86.9 MB/s
# ...
#      |████████████████████████████████| 158 kB 85.7 MB/s
# ...

# %%
DATAD_DIR = "../data"
CKPT_DIR = "../checkpoints"

# %%
# %cd finetuning

# !python3 train.py \
    --batch_size 2 \
    --num_workers 2 \
    --classifier_lr 1e-4 \
    --wav2vec2_lr 1e-5 \
    --max_epochs 3 \
    --accelerator gpu \
    --weight_decay 0.001 \
    --warmup_steps 0.1 \
    --constant_steps 0.4 \
    --scheduler_factor 0.001 \
    --data_dir $DATAD_DIR \
    --ckpt_dir $CKPT_DIR \
    --grad_clip 1.0
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 1: : 23242it [2:03:34,  3.13it/s, loss=0.665, v_num=gyxe]
# Epoch 1: : 23243it [2:03:34,  3.13it/s, loss=0.665, v_num=gyxe]
# Epoch 1: : 23244it [2:03:34,  3.13it/s, loss=0.665, v_num=gyxe]
# Epoch 1: : 23245it [2:03:35,  3.13it/s, loss=0.665, v_num=gyxe]
# Epoch 1: : 23246it [2:03:35,  3.13it/s, loss=0.665, v_num=gyxe]
# Epoch 1: : 23247it [2:03:35,  3.13it/s, loss=0.665, v_num=gyxe]
# Epoch 1: : 23248it [2:03:35,  3.14it/s, loss=0.665, v_num=gyxe]
# Epoch 1: : 23249it [2:03:35,  3.14it/s, loss=0.665, v_num=gyxe]
# Epoch 1: : 23250it [2:03:35,  3.14it/s, loss=0.665, v_num=gyxe]
# Epoch 1: : 23251it [2:03:35,  3.14it/s, loss=0.665, v_num=gyxe]
# Epoch 1: : 23252it [2:03:35,  3.14it/s, loss=0.665, v_num=gyxe]
# Epoch 1: : 23253it [2:03:36,  3.14it/s, loss=0.665, v_num=gyxe]
# Epoch 1: : 23254it [2:03:36,  3.14it/s, loss=0.665, v_num=gyxe]
# Epoch 1: : 23255it [2:03:36,  3.14it/s, loss=0.665, v_num=gyxe]
# ...
