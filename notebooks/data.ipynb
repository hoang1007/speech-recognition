# %%
import torchaudio as tau

waveform, rate = tau.load("../data/vlsp2020_train_set_02/database_sa1_Jan08_Mar19_cleaned_utt_0000000005-1.wav")
waveform.shape
# Out:
# torch.Size([1, 139200])

# %%
rate
# Out:
# 16000

# %%
import torch

mask_time_indices = torch.tensor([[0, 0, 0, 0, 1, 0]])
target = ((1 - mask_time_indices.long()) * -100).transpose(0, 1).flatten()
target
# Out:
# tensor([-100, -100, -100, -100,    0, -100])

# %%
from IPython.display import Audio

Audio(waveform.flatten(), rate=rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import torch, einops

x = torch.rand((4, 10, 4, 8, 32))
einops.reduce(x, 'a b c d e -> a b (c e)', 'sum').shape
# Out:
# torch.Size([4, 10, 128])

# %%
(waveform[0] - waveform[1]).sum()
# Out:
# tensor(0.2123)

# %%
waveform[1]
# Out:
# tensor([0.0000, 0.0000, 0.0000,  ..., 0.0017, 0.0019, 0.0011])

# %%
waveform.shape
# Out:
# torch.Size([2, 146432])
